# %%
#seaborn
#visualisation pattern like matlipplot
#it have quality figure ,colour make the visual more attrative
#it have default dataset ,for that we use sns.load_dataset

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
df#target variable is tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.value_counts("size")
#df.value_counts("day")
#df.pivot_table(columns=["day"],aggfunc="size")
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# dtype: int64

# %%
#central tendency:
#mean,median,mode
#mean and median :used for data that can be measured
#mode is used for catrgorical data eg:value count

# %%
df["day"].mode()
# Out:
# 0    Sat
# Name: day, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df["tip"].median()
# Out:
# 2.9

# %%
df.value_counts("day")
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# dtype: int64

# %%
df.value_counts('sex')
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %%
# refer seaborn notes

# %%
d = sns.load_dataset("titanic")
d
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.pairplot(d)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
import seaborn as sns

# %%
d = sns.load_dataset("titanic")
d
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.pairplot(d)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
pip show numpy
# Out:
# Name: numpy
# Version: 1.20.3
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD
# Location: /Users/divyabalu/opt/anaconda3/lib/python3.9/site-packages
# Requires:
# Required-by: tifffile, tables, statsmodels, seaborn, scipy, scikit-learn, scikit-image, PyWavelets, pyerfa, patsy, pandas, numexpr, numba, mkl-random, mkl-fft, matplotlib, imageio, imagecodecs, h5py, daal4py, Bottleneck, bokeh, bkcharts, astropy
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.heatmap(df.corr())
#how much the tip size and bill are correlated
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind="reg")

# %%
sns.pairplot(d,hue="sex")
# Out:
# /Users/divyabalu/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
#frequency id used in continous variables or column

# %%
### Categorical Plots
#eg:gender,size 

#Seaborn also helps us in doing the analysis on Categorical Data points. 
#In this section we will discuss about

#- boxplot
#- violinplot
#- countplot
#- bar plot

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#countplot
#seaborn.countplot() method is used to Show the 
#counts of observations in each categorical bin using bars.
 
sns.countplot("sex",data=df)
# Out:
# /Users/divyabalu/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
#note it down//////
df.pivot_table(columns=['day'], aggfunc='size')
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# dtype: int64

# %%
df.pivot_table(columns=["sex"],aggfunc="size")
# Out:
# sex
# Male      157
# Female     87
# dtype: int64

# %%
df.info()

# %%
sns.countplot(y="sex",data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='sex'>

# %%
sns.countplot("day",data=df)
# Out:
# /Users/divyabalu/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.countplot("smoker",data=df)
# Out:
# /Users/divyabalu/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot("time",data=df)
# Out:
# /Users/divyabalu/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
df.pivot_table(columns="time",aggfunc="size")
# Out:
# time
# Lunch      68
# Dinner    176
# dtype: int64

# %%
## Bar plot
sns.barplot(x='total_bill',y='sex',data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='sex'>

# %%
sns.barplot(y="time",x="total_bill",data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='time'>

# %%
#difference with join and bar plot
#dealing with numerical in join where as in bar we r using categorical

# %%
sns.barplot(x="total_bill",y="smoker",data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='smoker'>

# %%
sns.barplot(x="day",y="total_bill",data=df)#here,we understoond that in sat and sun 
#there is a hike in customer walkin,we need to make more food
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
## Box plot
#to find outliers
#A box and whisker plot (sometimes called a boxplot) is a graph that presents 
#information from a five-number summary.
#A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons 
#between variables or across levels of a categorical variable.

# %%
sns.boxplot("smoker","total_bill",data=df)
# Out:
# /Users/divyabalu/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot("day","total_bill",data=df)#with respect with day we draw total bill
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(df["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
df["total_bill"].median()
# Out:
# 17.795

# %%
sns.boxplot("total_bill",data=df)
# Out:
# /Users/divyabalu/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.histplot(df["total_bill"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.boxplot("tip","time",data=df)
# Out:
# /Users/divyabalu/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip', ylabel='time'>

# %%
sns.boxplot(x="smoker",y="total_bill",data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(data=df,orient="h")#orient =horizontal (h),vertical(v)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x="total_bill",y="day",hue="sex",data=df)#no manual legend ,here its automatic
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
### Violin Plot
#same as boxplot
#tip points indicates outliers
#Violin plot helps us to see both the 
#distribution of data in terms of Kernel density estimation and the box plot

# %%
sns.violinplot(x="total_bill",y="day",data=df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.distplot(df['tip'])
#
# Out:
# /Users/divyabalu/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
df["day"].mode()
# Out:
# 0    Sat
# Name: day, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
df["tip"].mean()
# Out:
# 2.9982786885245902

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df["tip"].median()
# Out:
# 2.9

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000
