# %%
import pandas as pd

# %%
file = pd.read_csv("data/supermarket_sales.csv")

# %%
file
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 0         Health and beauty       74.69         7  26.1415  548.9715
# 1    Electronic accessories       15.28         5   3.8200     80.22
# 2        Home and lifestyle       46.33         7  16.2155  340.5255
# ...

# %%
file.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                       object
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   object
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
file.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  \
# 0       Health and beauty       74.69         7  26.1415  548.9715
# 1  Electronic accessories       15.28         5   3.8200     80.22
# 2      Home and lifestyle       46.33         7  16.2155  340.5255
# 3       Health and beauty       58.22         8  23.2880   489.048
# 4       Sports and travel       86.31         7  30.2085  634.3785
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 0  01-05-2019  13:08      Ewallet  522.83                 4.761905
# 1  03-08-2019  10:29         Cash   76.40                 4.761905
# ...

# %%
file.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%    Total        Date   Time  Payment  \
# 995       40.35         1   2.0175  42.3675   1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.49  03-02-2019  17:16  Ewallet
# 997       31.84         1   1.5920   33.432  02-09-2019  13:22     Cash
# 998       65.82         1   3.2910   69.111   2/22/2019  15:33     Cash
# 999       88.34         7  30.9190  649.299   2/18/2019  13:28     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
file["gross income"].mean()  #average
# Out:
# 15.379369000000002

# %%
file["gross income"].median()
# Out:
# 12.088000000000001

# %%
file["Gender"].mode()
# Out:
# 0    Female
# dtype: object

# %%
file["Gender"].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
file["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
file["Gender"].nunique()
# Out:
# 2

# %%
file.describe(include = "O")#only object//for category type
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
#
#           Total        Date   Time  Payment
# count      1000        1000   1000     1000
# unique      990          89    506        3
# top     216.846  02-07-2019  19:48  Ewallet
# freq          2          20      7      345

# %%
file.describe(include = "all")#both numerical and categorical
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# 75%             NaN    NaN     NaN           NaN     NaN                  NaN
# max             NaN    NaN     NaN           NaN     NaN                  NaN
#
# ...

# %%
file["Customer type"].nunique()
# Out:
# 2

# %%
totalGrossIncome=file["gross income"].sum() #total gross income

# %%
print("Total GI",totalGrossIncome)
# Out:
# Total GI 15379.368999999999

# %%
#MOST COMMONLY USED PAYMENT TYPE:
file["Payment"].mode()[0]
# Out:
# 'Ewallet'

# %%
#average unit price of a product:
avg=file["Unit price"].mean()
print(f"the avg is {avg}")
print(f"{avg} the avg u p")
# Out:
# the avg is 55.67212999999998
# 55.67212999999998 the avg u p

# %%
#what is the standard deviation of product unit price ?
UnitPriceSTD=file["Unit price"].std()

# %%
UnitPriceSTD
# Out:
# 26.494628347919768

# %%
 #what is the total number of sales ?
file["Invoice ID"].nunique()
# Out:
# 1000

# %%
file["Invoice ID"].size
# Out:
# 1000

# %%
file["Invoice ID"].count()
# Out:
# 1000

# %%
file["Invoice ID"].shape[0]
# Out:
# 1000

# %%
file["Invoice ID"].value_counts()#there is no repeat value so it will show first 5 and last 5//
# Out:
# 750-67-8428    1
# 642-61-4706    1
# 816-72-8853    1
# 491-38-3499    1
# 322-02-2271    1
#               ..
# 633-09-3463    1
# 374-17-3652    1
# 378-07-7001    1
# 433-75-6987    1
# 849-09-3807    1
# Name: Invoice ID, Length: 1000, dtype: int64

# %%
#what are the diffent type of product line
file["Product line"].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
##PROBLEM ::2
data=pd.read_csv("data/adult.csv")

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
head=data.head()
tail=data.tail()
shape=data.shape
size=data.size
tail
size
# Out:
# 732630

# %%
head
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
tail
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %%
head
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
shape
# Out:
# (48842, 15)

# %%
size
# Out:
# 732630

# %%
data.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
info=data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
data.describe(include = "O")
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      48842     48842               48842           48842        48842
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       33906     15784               22379            6172        19716
#
#          race gender native-country income
# count   48842  48842          48842  48842
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    41762  32650          43832  37155

# %%
describe = data.describe(include ="all")

# %%
describe
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   48842.000000     48842  4.884200e+04     48842     48842.000000
# unique           NaN         9           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33906           NaN     15784              NaN
# mean       38.643585       NaN  1.896641e+05       NaN        10.078089
# std        13.710510       NaN  1.056040e+05       NaN         2.570973
# min        17.000000       NaN  1.228500e+04       NaN         1.000000
# 25%        28.000000       NaN  1.175505e+05       NaN         9.000000
# 50%        37.000000       NaN  1.781445e+05       NaN        10.000000
# 75%        48.000000       NaN  2.376420e+05       NaN        12.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status      occupation relationship   race gender  \
# ...

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
#avg work per week for both male and female::
hr=data["hours-per-week"].mean()

# %%
hr
# Out:
# 40.422382375824085

# %%
data.groupby("gender")['hours-per-week'].mean()##cateorgy data
# Out:
# gender
# Female    36.400692
# Male      42.416845
# Name: hours-per-week, dtype: float64

# %%
work=data["workclass"].unique()
work
## ?:missing value
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
#with working class and gender::
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data["workclass"].mode()[0]
# Out:
# 'Private'

# %%
data["workclass"].value_counts()# missing value impute
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
data.groupby(['workclass','gender'])['hours-per-week'].mean()
# Out:
# workclass         gender
# ?                 Female    29.914961
#                   Male      33.388489
# Federal-gov       Female    39.882743
#                   Male      42.265306
# Local-gov         Female    39.014308
#                   Male      42.075080
# Never-worked      Female    23.333333
#                   Male      31.285714
# Private           Female    36.510647
#                   Male      42.229524
# Self-emp-inc      Female    42.398104
#                   Male      49.448113
# Self-emp-not-inc  Female    37.227345
#                   Male      45.789669
# State-gov         Female    36.901704
#                   Male      40.462233
# Without-pay       Female    32.285714
#                   Male      34.785714
# Name: hours-per-week, dtype: float64

# %%
data.describe(include="O")
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      48842     48842               48842           48842        48842
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       33906     15784               22379            6172        19716
#
#          race gender native-country income
# count   48842  48842          48842  48842
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    41762  32650          43832  37155

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data.groupby(["gender","race","workclass"])['hours-per-week'].mean()#befoe max displays row
# Out:
# gender  race                workclass
# Female  Amer-Indian-Eskimo  ?                   31.789474
#                             Federal-gov         37.684211
#                             Local-gov           37.516129
#                             Private             37.530000
#                             Self-emp-inc        40.000000
#                                                   ...
# Male    White               Private             42.466993
#                             Self-emp-inc        49.308518
#                             Self-emp-not-inc    45.843522
#                             State-gov           40.605010
#                             Without-pay         36.250000
# Name: hours-per-week, Length: 77, dtype: float64

# %%
data["race"].value_counts()
# Out:
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
pd.set_option("display.max_rows",100)

# %%
data.groupby(["gender","race","workclass"])['hours-per-week'].mean() #it display 100
# Out:
# gender  race                workclass
# Female  Amer-Indian-Eskimo  ?                   31.789474
#                             Federal-gov         37.684211
#                             Local-gov           37.516129
#                             Private             37.530000
#                             Self-emp-inc        40.000000
#                             Self-emp-not-inc    35.833333
#                             State-gov           41.555556
#         Asian-Pac-Islander  ?                   28.617021
#                             Federal-gov         41.294118
#                             Local-gov           38.050000
#                             Private             37.573370
#                             Self-emp-inc        46.750000
#                             Self-emp-not-inc    43.277778
#                             State-gov           35.225806
#         Black               ?                   33.629834
#                             Federal-gov         40.057851
# ...

# %%
outputDF=data.groupby(["race","gender","workclass"])["age","hours-per-week"].mean()
# Out:
# /var/folders/x9/53_ys47x1pn2rbqnxc60stsm0000gn/T/ipykernel_20781/1847760000.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   outputDF=data.groupby(["race","gender","workclass"])["age","hours-per-week"].mean()

# %%
#we can save this data in new excel::
outputDF
# Out:
#                                                   age  hours-per-week
# race               gender workclass
# Amer-Indian-Eskimo Female ?                 33.684211       31.789474
#                           Federal-gov       41.526316       37.684211
#                           Local-gov         38.516129       37.516129
#                           Private           33.830000       37.530000
#                           Self-emp-inc      46.000000       40.000000
#                           Self-emp-not-inc  38.833333       35.833333
#                           State-gov         46.555556       41.555556
#                    Male   ?                 49.062500       38.875000
#                           Federal-gov       41.714286       40.928571
#                           Local-gov         39.029412       41.000000
#                           Private           33.926966       42.168539
#                           Self-emp-inc      42.000000       30.000000
# ...

# %%
type(outputDF)
# Out:
# pandas.core.frame.DataFrame

# %%
#to csv::
outputDF.to_csv("sample.csv")

# %%
#to excel::
outputDF.to_excel("new..xlsx")

# %%
df_customer = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['Tom', 'Jenny', 'James', 'Dan'],
})

# %%
df_customer#table1
# Out:
#    id   name
# 0   1    Tom
# 1   2  Jenny
# 2   3  James
# 3   4    Dan

# %%
df_info = pd.DataFrame({
    'id': [2, 3, 4, 5],
    'age': [31, 20, 40, 70],
    'sex': ['F', 'M', 'M', 'F']
})

# %%
df_info#table2
# Out:
#    id  age sex
# 0   2   31   F
# 1   3   20   M
# 2   4   40   M
# 3   5   70   F

# %%
pd.merge(df_customer, df_info)#By default, the function will combine data on common columns (It is the column id in our example) and produces only the result that matches in both left and right DataFrames.

#The following is an equivalent statement if you prefer to call merge from the left DataFrame.
# Out:
#    id   name  age sex
# 0   2  Jenny   31   F
# 1   3  James   20   M
# 2   4    Dan   40   M

# %%
df_customer.merge(df_info)
# Out:
#    id   name  age sex
# 0   2  Jenny   31   F
# 1   3  James   20   M
# 2   4    Dan   40   M

# %%
##### 2. Specifying key columns using argument on

#You can specify the common columns for merging. 

#To do so, pass an additional argument on as the name of the common column, here 'id' in our example, to merge() function:

# %%
pd.merge(df_customer,df_info, on='id')
# Out:
#    id   name  age sex
# 0   2  Jenny   31   F
# 1   3  James   20   M
# 2   4    Dan   40   M

# %%
df_order = pd.DataFrame({
    'id': [2,3,4,5],
    'name': ['Jenny', 'James', 'Dan', 'leo'],
    'quantity': [2,4,6,10]
})
df_order
# Out:
#    id   name  quantity
# 0   2  Jenny         2
# 1   3  James         4
# 2   4    Dan         6
# 3   5    leo        10

# %%
df_customer
# Out:
#    id   name
# 0   1    Tom
# 1   2  Jenny
# 2   3  James
# 3   4    Dan

# %%
pd.merge(df_customer,df_order,on="id")
# Out:
#    id name_x name_y  quantity
# 0   2  Jenny  Jenny         2
# 1   3  James  James         4
# 2   4    Dan    Dan         6

# %%
pd.DataFrame({
    "id":[2,3,4,5],
    "name":['Jenny', 'James', 'Dan', 'leo'],
     "quantity": [2,4,6,10]
})
# Out:
#    id   name  quantity
# 0   2  Jenny         2
# 1   3  James         4
# 2   4    Dan         6
# 3   5    leo        10

# %%
pd.merge(df_customer,df_order,on=["id","name"])#here there is no namex or name y
# Out:
#    id   name  quantity
# 0   2  Jenny         2
# 1   3  James         4
# 2   4    Dan         6

# %%
pd.merge(df_customer,df_order,on="id")
# Out:
#    id name_x name_y  quantity
# 0   2  Jenny  Jenny         2
# 1   3  James  James         4
# 2   4    Dan    Dan         6

# %%
##### 3. Merging using left_on and right_on

#It might happen that the column on which you want to merge the DataFrames have different names. For such merges, you will have to specify the left_on as the left DataFrame name and right_on as the right DataFrame name, for example:

# %%
df_info_2 = pd.DataFrame({
    'customer_id': [2,3,4,5],
    'age': [31,20,40,70],
    'sex': ['F', 'M', 'M', 'F']
})
df_info_2
# Out:
#    customer_id  age sex
# 0            2   31   F
# 1            3   20   M
# 2            4   40   M
# 3            5   70   F

# %%
df_customer
# Out:
#    id   name
# 0   1    Tom
# 1   2  Jenny
# 2   3  James
# 3   4    Dan

# %%
pd.merge(
df_customer,
df_info_2,
left_on="customer_id",
right_on="id"
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/x9/53_ys47x1pn2rbqnxc60stsm0000gn/T/ipykernel_20781/3035078129.py in <module>
# ----> 1 pd.merge(
#       2 df_customer,
#       3 df_info_2,
#       4 left_on="customer_id",
#       5 right_on="id"
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
# ...

# %%
##### 4. Various type of joins: inner, left, right and outer

# %%
df_customer = pd.DataFrame({
    'id': [1,2,3,4],
    'name': ['Tom', 'Jenny', 'James', 'Dan'],
})
df_info = pd.DataFrame({
    'id': [2,3,4,5],
    'age': [31,20,40,70],
    'sex': ['F', 'M', 'M', 'F']
})
#pd.merge(df_customer, df_info, on='id', how=?) HERE IT WILL SHOW A HOW

# %%
##### 4.1 inner join

#By default, Pandas merge() is performing the inner join and it produces only the set of records that match in both DataFrame.

# %%
pd.merge(df_customer,df_info, how="inner" ,on="id")

# %%
##### 4.2 left join

#The left join produces all records from the left DataFrame, and the matched records from the right DataFrame. If there is no match, the left side will contain NaN. You can set the argument how='left' to do left join:

# %%
pd.merge(df_customer,df_info,how="left",on="id")#it is showing NaN:because it includes only left

# %%
pd.merge(df_customer,df_info,how="right",on="id")

# %%
pd.merge(df_customer,df_info,how="outer",on="id")

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35,38],
    "humidity": [65,68,71, 75]
})
df1

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})
df2

# %%
pd.merge(df1,df2, on="city",how="outer")

# %%
#### Additional Parameters
###### Indicator flag

# %%
data_in = pd.merge(df1,df2,on="city",how="outer",indicator=True)

# %%
data_in

# %%
#### Suffixes

# %%
pd.merge(df1,df2,on="city",how="outer")

# %%
pd.merge(df1,df2,on='city',how="outer",suffixes=('_x', '_y'))

# %%
#add another name::::
pd.merge(df1,df2,on="city",how="outer",suffixes=("_first","_second"))

# %%
#JOIN
##### Join

#Join columns of another DataFrame.

#Join columns with other DataFrame either on index or on a key column. Efficiently join multiple DataFrame objects by index at once by passing a list.

# %%
Pdf1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
Pdf1

# %%
Pdf1 = pd.DataFrame({
    "city1": ["new york","chicago","orlando"],
    "temperature": [21,14,35]
})
Pdf1.set_index('city1',inplace=True)
Pdf1

# %%
df2 = pd.DataFrame({
    "city1": ["chicago","new york","orlando"],
    "humidity": [65,68,75]
})
#df2.set_index('city',inplace=True)
df2

# %%
Pdf1.join(df2)#with respect to index

# %%
Pdf1 = pd.DataFrame({
    "city1": ["new york","chicago","orlando"],
    "temperature": [21,14,35]
})
Pdf1

# %%
Pdf1.join(df2)#there will be error so v have change city as set.index

# %%
##### Concatenating
#In order to concat dataframe, we use concat() function which helps in concatenating a dataframe.
#We can concat a dataframe in many different ways, they are:

# %%
import pandas as pd
# Define a dictionary containing employee data 
data1 = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj','Ijas'], 
        'Age':[27, 24, 22, 32,50] ,
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj','Kerala'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd','Btech']} 
   
# Define a dictionary containing employee data 
data2 = {'Name':['Abhi', 'Ayushi', 'Dhiraj', 'Hitesh','Ijas'], 
        'Age':[17, 14, 12, 52,50], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj','Tamil Nadu'], 
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons','Btech']}

# %%
df = pd.DataFrame(data1,index=[1,2,3,4,5])

# %%
df

# %%
df2 = pd.DataFrame(data2,index=[6,7,8,9,10])

# %%
df2

# %%
print(df ,"\n\n",df2)

# %%
# Now apply .concat function in order to concat two dataframe

# using a .concat() method
frames=[df,df2]
res=pd.concat(frames)
res

# %%
pd.concat([df,df2],axis=1)#we can do like this also

# %%
##### Drop Duplicates
res.drop_duplicates(["Name"])#when we specify names ,it will drop the duplicates

# %%
res.drop_duplicates(["Name"],keep="last")

# %%
res.drop_duplicates(["Name"],keep="first")

# %%
df = pd.DataFrame(data1)
df

# %%
df2 = pd.DataFrame(data2)

# %%
df2

# %%
##### Ignore Index
pd.concat([df,df2],ignore_index=True,verify_integrity=False)

# %%
pd.concat([df,df2])

# %%
k = pd.concat([df,df2],keys=["key1","key2"])

# %%
k

# %%
k.loc["key1"]

# %%
k.loc["key2"]

# %%
k.to_csv("sam.csv")

# %%
k.loc["key2"]

# %%
##### Concatenating DataFrame using .append()

# %%
res=df.append(df2)
res

# %%
##### Pandas - Plotting

#Pandas uses the plot() method to create diagrams.


#We can use Pyplot, a submodule of the Matplotlib library to visualize the diagram on the screen.

#Read more about Matplotlib in our Matplotlib Tutorial.

# %%
new_d = pd.read_csv("data/data.csv")

# %%
new_d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/x9/53_ys47x1pn2rbqnxc60stsm0000gn/T/ipykernel_20781/3017584237.py in <module>
# ----> 1 new_d
#
# NameError: name 'new_d' is not defined
